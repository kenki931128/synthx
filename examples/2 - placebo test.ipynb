# %%
import synthx as sx

# %% [markdown]
# ### significant difference

# %%
df = sx.sample(
    n_units=20,
    n_time=50,
    n_observed_covariates=3,
    n_unobserved_covariates=10,
    intervention_units=[1, 2],
    intervention_time=40,
    intervention_effect=1.08,
    noise_effect=0.5,
    scale=2,
    seed=42,
)

# %%
dataset = sx.Dataset(
    df,
    unit_column='unit',
    time_column='time',
    y_column='y',
    covariate_columns=['covariate_1', 'covariate_2', 'covariate_3'],
    intervention_units=[1, 2],
    intervention_time=40,
)

# %%
effect_test, effects_placebo, sc_test, scs_placebo = sx.placebo_test(dataset)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 152.54it/s]

# %%
sc_test.plot()

# %%
scs_placebo[1].plot()

# %%
effect_test, effects_placebo
# Out:
# ([1.4596925898094644, 1.0152039341892674],
#  [-0.15760113551022023,
#   -0.2027736011596645,
#   0.10607226812008619,
#   0.14708350641324072,
#   -0.14206542269491587,
#   -0.4324635531306845,
#   0.5001655983402404,
#   0.5270991174579139,
#   0.04832192028722244,
#   0.4339741681558935,
#   -0.3404094473290396,
#   -0.5639503412854637,
#   -0.3902744799754206,
#   -0.05108029109732423,
#   0.34791427830019317,
#   0.09304380886100694,
#   0.306410741944344,
#   -0.6724944373313834])

# %%
sx.stats.calc_p_value(effect_test, effects_placebo)
# Out:
# 0.0001951423711662043
