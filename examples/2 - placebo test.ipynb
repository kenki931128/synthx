# %%
import synthx as sx

# %% [markdown]
# ### significant difference

# %%
df = sx.sample(
    n_units=20,
    n_time=50,
    n_observed_covariates=3,
    n_unobserved_covariates=1,
    intervention_units=1,
    intervention_time=40,
    intervention_effect=1,
    seed=42,
)

# %%
dataset = sx.Dataset(
    df,
    unit_column = 'unit',
    time_column = 'time',
    y_column = 'y',
    covariate_columns = ['covariate_1', 'covariate_2', 'covariate_3'],
    intervention_units=1,
    intervention_time=40,
)

# %%
effect_test, effects_placebo, sc_test, scs_placebo = sx.placebo_test(dataset)

# %%
sc_test.plot()

# %%
scs_placebo[1].plot()

# %%
effect_test, effects_placebo
# Out:
# (0.9974311458710733,
#  [0.019987665894237283,
#   0.057426995361249955,
#   -0.013577340624467079,
#   0.006499987659376316,
#   -0.03726749089375704,
#   0.0016996457206451578,
#   0.022934619768955944,
#   0.012130184163667623,
#   -0.0227103450400697,
#   -0.048908676519937244,
#   -0.04633153491997889,
#   -0.04553881840116891,
#   -0.010540085063995952,
#   0.10417281128942692,
#   -0.021044070838929993,
#   0.015275921906809792,
#   -0.01160952354371847,
#   -0.00917934207901744,
#   -0.10687194230037295])

# %%
sx.stats.calc_p_value(effect_test, effects_placebo)
# Out:
# 1.7649097424686248e-14
