# %%
import synthx as sx

# %% [markdown]
# ### significant difference

# %%
df = sx.sample(
    n_units=20,
    n_time=50,
    n_observed_covariates=3,
    n_unobserved_covariates=10,
    intervention_units=[1, 2],
    intervention_time=40,
    intervention_effect=1.08,
    noise_effect=0.5,
    scale=2,
    seed=42,
)

# %%
dataset = sx.Dataset(
    df,
    unit_column='unit',
    time_column='time',
    y_column='y',
    covariate_columns=['covariate_1', 'covariate_2', 'covariate_3'],
    intervention_units=[1, 2],
    intervention_time=40,
)

# %%
effects_test, effects_placebo, sc_test, scs_placebo = sx.placebo_test(dataset)
# Out:
# 100%|██████████████████████████████████████████| 18/18 [00:00<00:00, 216.45it/s]

# %%
sc_test.plot()

# %%
scs_placebo[1].plot()

# %%
effects_test, effects_placebo
# Out:
# ([0.11294977804137435, 0.08368308871256647],
#  [-0.01424858262819507,
#   -0.01725675557262033,
#   0.005702777158526718,
#   0.009619970076445624,
#   -0.012087964494144206,
#   -0.035431932697022155,
#   0.045502873506560876,
#   0.04355792878984918,
#   0.007423395468788176,
#   0.04737796532336655,
#   -0.03177504825272956,
#   -0.030232628067611816,
#   -0.032520846130347315,
#   0.0003489016334268877,
#   0.04021425584323188,
#   0.005191411215221302,
#   0.0259619758944766,
#   -0.055540927277926096])

# %%
sx.stats.calc_p_value(effects_test, effects_placebo)
# Out:
# 0.00045640611566501096
