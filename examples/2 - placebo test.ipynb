# %%
import synthx as sx

# %% [markdown]
# ### significant difference

# %%
df = sx.sample(
    n_units=20,
    n_time=50,
    n_observed_covariates=3,
    n_unobserved_covariates=10,
    intervention_units=[1, 2],
    intervention_time=40,
    intervention_effect=1.08,
    noise_effect=0.2,
    scale=2,
    seed=42,
)

# %%
dataset = sx.Dataset(
    df,
    unit_column='unit',
    time_column='time',
    y_column='y',
    covariate_columns=['covariate_1', 'covariate_2', 'covariate_3'],
    intervention_units=[1, 2],
    intervention_time=40,
)

# %%
effects_test, effects_placebo, sc_test, scs_placebo = sx.placebo_test(dataset)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 231.51it/s]

# %%
sc_test.plot()

# %%
scs_placebo[1].plot()

# %%
effects_test, effects_placebo
# Out:
# ([0.09373140907367762, 0.08761017171182997],
#  [-0.0027222819860865605,
#   -0.02043114811857701,
#   -0.0031964768631844963,
#   0.0020997019340117445,
#   -0.025787279177667276,
#   -0.017076899714513788,
#   0.02374274859562117,
#   0.021132499709280363,
#   0.01042154033069899,
#   0.020605098559051606,
#   -0.039131570024440857,
#   0.033447564859534054,
#   -0.008885945562953397,
#   0.008058496185349949,
#   0.02506234774428364,
#   0.004251835730975789,
#   0.0203727850630982,
#   -0.010279213732308222])

# %%
sx.stats.calc_p_value(effects_test, effects_placebo)
# Out:
# 9.401412452002719e-06
